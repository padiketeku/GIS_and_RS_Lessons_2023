# %%
# Import necessary packages
import matplotlib.pyplot as plt
import pandas as pd

# Create data
boulder_precip = pd.DataFrame(columns=["date", "precip"], 
                              data=[
                                  ["2013-09-09", 0.1], ["2013-09-10", 1.0], 
                                  ["2013-09-11", 2.3], ["2013-09-12", 9.8], ["2013-09-13", 1.9],
                                  ["2013-09-14", 0.01], ["2013-09-15", 1.4], ["2013-09-16", 0.4]])      
# Create plot
fig, ax = plt.subplots()
ax.bar(boulder_precip['date'].values, boulder_precip['precip'].values)
ax.set(title="Daily Precipitation (inches)\nBoulder, Colorado 2013", 
       xlabel="Date", ylabel="Precipitation (Inches)")
plt.setp(ax.get_xticklabels(), rotation=45);

# %%
16-4

# %%
24/4

# %%
2*4

# %%
2**4

# %% [markdown]
# # heading 1
# ## heading 2
# * point 1
# 1. point 2

# %% [markdown]
# *key elements are unknown*
# **key elements are unknown*
# * **take note of this point**
# `remember this code!`
# ```they will be helpful```
# ***
# take note of the codes given you
# ***
#
# Charles Sturt Uni is online via <a href="https://www.csu.edu.au/" target="_blank">this link</a>

# %% [markdown]
# ## Intro to Earth Analytics - Chapter Four
# * **Author:** Crabbe
# * **Date:** 8 July 2022

# %% [markdown]
# * *guava*
# * mangoes You can find Australian <a href="https://mangoes.net.au/" target="_blank">mangoes here</a>
# * avocadoes ![eat avocadoes] (https://grazegroceries.com/hass-jumbo-avocados)

# %% [markdown]
# ## The use of tabular data for earth data science

# %%
# import packages
import os
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Download and open the .csv file using pandas
avg_monthly_precip=pd.read_csv( "https://ndownloader.figshare.com/files/12710618")

# view the downloaded data 
avg_monthly_precip
# Out:
#    months  precip seasons
# 0     Jan    0.70  Winter
# 1     Feb    0.75  Winter
# 2     Mar    1.85  Spring
# 3     Apr    2.93  Spring
# 4     May    3.05  Spring
# 5    June    2.02  Summer
# 6    July    1.93  Summer
# 7     Aug    1.62  Summer
# 8    Sept    1.84    Fall
# 9     Oct    1.31    Fall
# 10    Nov    1.39    Fall
# 11    Dec    0.84  Winter

# %%
# stats about the data frame
avg_monthly_precip.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   months   12 non-null     object
#  1   precip   12 non-null     float64
#  2   seasons  12 non-null     object
# dtypes: float64(1), object(2)
# memory usage: 416.0+ bytes

# %%
# plot this data using .plot()
f,ax=plt.subplots()
avg_monthly_precip.plot(x="months", y="precip", title="Precipitation (mm) for one year", ax=ax)
ax.set(xlabel='Month', ylabel='Precipitation (mm)')
plt.show()

# %%
# determine the type of data stored in the avg_monthly_precip
avg_monthly_precip.dtypes
# Out:
# months      object
# precip     float64
# seasons     object
# dtype: object

# %%
# chanage to bar chart and change the colour too
f,ax=plt.subplots()
avg_monthly_precip.plot(x="months", y="precip", kind="bar", color="purple", title="Precipitation (mm) for one year", ax=ax)
ax.set(xlabel='Month', ylabel='Precipitation (mm)')
plt.show()

# %%
# cleaning data so you can open it in python
# Open temperature data for Miami, Florida
miami_temp_url = "https://www.ncdc.noaa.gov/cag/city/time-series/USW00012839-tmax-12-12-1895-2020.csv"

miami_temp = pd.read_csv(miami_temp_url)
miami_temp
# Out:
#                         Miami  Florida   Maximum Temperature  \
# 0   Units: Degrees Fahrenheit      NaN                   NaN
# 1                Missing: -99      NaN                   NaN
# 2                        Date    Value                   NaN
# 3                      194812     83.2                   NaN
# 4                      194912     82.6                   NaN
# ..                        ...      ...                   ...
# 71                     201612     84.6                   NaN
# 72                     201712     85.9                   NaN
# 73                     201812     84.5                   NaN
# 74                     201912     85.9                   NaN
# 75                     202012     85.8                   NaN
#
#      January-December
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ..                ...
# 71                NaN
# 72                NaN
# ...

# %%
# remove the rows that have no data and re-assign missing data to NA
# Open the Miami data skipping the first 3 rows and setting no data values
miami_temp = pd.read_csv(miami_temp_url,
                         skiprows=3,
                         na_values=-99)

# View the first 5 rows of the data
miami_temp.head()
# Out:
#      Date  Value
# 0  194812   83.2
# 1  194912   82.6
# 2  195012   81.9
# 3  195112   82.3
# 4  195212   82.9

# %%
# challenge 3: plot a line graph for the temperature data
f,ax=plt.subplots()
miami_temp.plot(x="Date", y="Value", kind="line", color="purple", title="Challenge 3 Plot: Temperature (Fahrenheit)- Miami, FL", ax=ax)
ax.set(xlabel='Date', ylabel='Temperature (Fahrenheit)')
plt.show()

# %% [markdown]
# # plot the temperature data for Seattle, Washington

# %%
# Open temperature data for Seattle, Washington
seattle_temp_url = "https://www.ncdc.noaa.gov/cag/city/time-series/USW00013895-tmax-1-5-1895-2020.csv"

seattle_temp = pd.read_csv(seattle_temp_url)
seattle_temp
# Out:
#                    Montgomery  Alabama   Maximum Temperature   May
# 0   Units: Degrees Fahrenheit      NaN                   NaN   NaN
# 1                Missing: -99      NaN                   NaN   NaN
# 2                        Date    Value                   NaN   NaN
# 3                      194805     87.7                   NaN   NaN
# 4                      194905     87.5                   NaN   NaN
# ..                        ...      ...                   ...   ...
# 71                     201605     85.0                   NaN   NaN
# 72                     201705     84.1                   NaN   NaN
# 73                     201805     87.9                   NaN   NaN
# 74                     201905     88.7                   NaN   NaN
# 75                     202005     85.0                   NaN   NaN
#
# [76 rows x 4 columns]

# %%
# Open the Seattle data skipping the first 3 rows and setting no data values
seattle_temp = pd.read_csv(seattle_temp_url,
                         skiprows=3,
                         na_values=-99)

# View the first 5 rows of the data
seattle_temp.head()
# Out:
#      Date  Value
# 0  194805   87.7
# 1  194905   87.5
# 2  195005   87.0
# 3  195105   86.5
# 4  195205   85.2

# %%
# challenge 4: plot a line graph for the temperature data
f,ax=plt.subplots()
seattle_temp.plot(x="Date", y="Value", kind="line", color="red", title="Challenge 4 Plot: Temperature (Fahrenheit)- Seattle, WT", ax=ax)
ax.set(xlabel='Date', ylabel='Temperature (Fahrenheit)')
plt.show()

# %% [markdown]
# # Challenge 5- downlaod a csv file from a url and read in this data using pandas

# %%
# Download greenhouse gas CO2 data
import urllib.request

greenhouse_gas_url = "ftp://aftp.cmdl.noaa.gov/data/trace_gases/co2/in-situ/surface/brw/co2_brw_surface-insitu_1_ccgg_MonthlyData.txt"

urllib.request.urlretrieve(url=greenhouse_gas_url,
                           filename="co2-emissions-barrow.csv")
# Out:
# ('co2-emissions-barrow.csv', <email.message.Message at 0x1b0b9f89dc0>)

# %%
# read the data in using pandas
co2_emissions_barrow=pd.read_csv('co2-emissions-barrow.csv', skiprows=149)
co2_emissions_barrow.info
#print(co2_emissions_barrow.to_string())
# Out:
# <bound method DataFrame.info of     site_code year month day hour minute second time_decimal value value_std_dev nvalue latitude longitude altitude elevation intake_height qcflag
# 0    BRW 1973 1 1 0 0 0 1973.0 -999.99 -99.99 0 71....
# 1    BRW 1973 2 1 0 0 0 1973.0849315068492 -999.99 ...
# 2    BRW 1973 3 1 0 0 0 1973.1616438356164 -999.99 ...
# 3    BRW 1973 4 1 0 0 0 1973.2465753424658 -999.99 ...
# 4    BRW 1973 5 1 0 0 0 1973.3287671232877 -999.99 ...
# ..                                                 ...
# 583  BRW 2021 8 1 0 0 0 2021.5808219178082 405.03 1...
# 584  BRW 2021 9 1 0 0 0 2021.6657534246576 408.0 1....
# 585  BRW 2021 10 1 0 0 0 2021.7479452054795 414.07 ...
# 586  BRW 2021 11 1 0 0 0 2021.8328767123287 419.81 ...
# 587  BRW 2021 12 1 0 0 0 2021.9150684931508 423.29 ...
#
# [588 rows x 1 columns]>

# %%
# challenge 5: plot a line graph for the co2 emissions data
f,ax=plt.subplots()
co2_emissions_barrow.plot(x="time_decimal", y="value", kind="line", color="blue", title="Challenge 5 Plot: CO2- Barrow, AK", ax=ax)
ax.set(xlabel='Date', ylabel='CO2')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\CSU-MSH\Miniconda\envs\earth-analytics-python\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\CSU-MSH\Miniconda\envs\earth-analytics-python\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\CSU-MSH\Miniconda\envs\earth-analytics-python\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'time_decimal'
#
# ...

# %% [markdown]
# # Spatial Data Formats for Earth Data Science

# %%
# Import necessary packages
import os

import matplotlib.pyplot as plt
import numpy as np
import geopandas as gpd
import rioxarray as rxr

# Earthpy is an earthlab package to work with spatial data
import earthpy as et
import earthpy.plot as ep

# Get data 
et.data.get_data("colorado-flood")

#set working directory
os.chdir(os.path.join(et.io.HOME, 'earth-analytics', 'data'))

# %%
# A data by name pre-DTM.tif would be used, so create a path to the data file
lidar_dtm_path = os.path.join("colorado-flood",
                              "spatial",
                              "boulder-leehill-rd",
                              "pre-flood",
                              "lidar",
                              "pre_DTM.tif")
lidar_dtm_path
# Out:
# 'colorado-flood\\spatial\\boulder-leehill-rd\\pre-flood\\lidar\\pre_DTM.tif'

# %%
#open the pre-DTM data using 'rioxarray'
# Read the data in and call it lidar_dtm (this is the variable name)
lidar_dtm = rxr.open_rasterio(lidar_dtm_path, masked=True)

#view the data 
lidar_dtm
# Out:
# <xarray.DataArray (band: 1, y: 2000, x: 4000)>
# [8000000 values with dtype=float32]
# Coordinates:
#   * band         (band) int32 1
#   * x            (x) float64 4.72e+05 4.72e+05 4.72e+05 ... 4.76e+05 4.76e+05
#   * y            (y) float64 4.436e+06 4.436e+06 ... 4.434e+06 4.434e+06
#     spatial_ref  int32 0
# Attributes:
#     scale_factor:  1.0
#     add_offset:    0.0

# %%
#view numpy array stored inside of the xarray.DataArray
lidar_dtm.values
# Out:
# array([[[      nan,       nan,       nan, ..., 1695.63  , 1695.4199,
#          1695.4299],
#         [      nan,       nan,       nan, ..., 1695.6   , 1695.5399,
#          1695.36  ],
#         [      nan,       nan,       nan, ..., 1695.38  , 1695.44  ,
#          1695.37  ],
#         ...,
#         [      nan,       nan,       nan, ..., 1681.45  , 1681.39  ,
#          1681.25  ],
#         [      nan,       nan,       nan, ..., 1681.72  , 1681.57  ,
#          1681.5599],
#         [      nan,       nan,       nan, ..., 1681.89  , 1681.8099,
#          1681.74  ]]], dtype=float32)

# %%
#check the data type
type(lidar_dtm)
# Out:
# xarray.core.dataarray.DataArray

# %%
# View the min and max values of the array
print(lidar_dtm.min(), lidar_dtm.max())
# Out:
# <xarray.DataArray ()>
# array(1676.21, dtype=float32)
# Coordinates:
#     spatial_ref  int32 0 <xarray.DataArray ()>
# array(2087.43, dtype=float32)
# Coordinates:
#     spatial_ref  int32 0

# %%
# View the dimensions of the array (rows, columns)
lidar_dtm.shape
# Out:
# (1, 2000, 4000)

# %% [markdown]
# ### Finally you can plot your data. For plotting you will use earthpy.plot_bands

# %%
ep.plot_bands(lidar_dtm,
              scale=False,
              cmap='Greys',
              title="Lidar Digital Terrain Model")
plt.show()

# %% [markdown]
# ## challenge 1: open and plot a raster dataset

# %%
# Add the code here to open, show, and close the raster dataset.

lidar_dtm_path_post_flood = os.path.join("data", "colorado-flood", "spatial",
                                         "boulder-leehill-rd", "post-flood", "lidar", "post_DTM.tif")

lidar_dtm_path_post_flood
# Out:
# 'data\\colorado-flood\\spatial\\boulder-leehill-rd\\post-flood\\lidar\\post_DTM.tif'

# %%
# Download NAIP data
et.data.get_data(url="https://ndownloader.figshare.com/files/23070791")
# Out:
# ...
# Extracted output to C:\Users\rcrabbe\earth-analytics\data\earthpy-downloads\naip-before-after
# 'C:\\Users\\rcrabbe\\earth-analytics\\data\\earthpy-downloads\\naip-before-after'

# %%
# Create a path for the data file - notice it is a .tif file
naip_pre_fire_path = os.path.join("earthpy-downloads",
                                  "naip-before-after",
                                  "pre-fire",
                                  "crop",
                                  "m_3910505_nw_13_1_20150919_crop.tif")

naip_pre_fire_path
# Out:
# 'earthpy-downloads\\naip-before-after\\pre-fire\\crop\\m_3910505_nw_13_1_20150919_crop.tif'

# %%
# Open the data using rioxarray
naip_pre_fire = rxr.open_rasterio(naip_pre_fire_path)

naip_pre_fire
# Out:
# <xarray.DataArray (band: 4, y: 2312, x: 4377)>
# [40478496 values with dtype=int16]
# Coordinates:
#   * band         (band) int32 1 2 3 4
#   * x            (x) float64 4.572e+05 4.572e+05 ... 4.615e+05 4.615e+05
#   * y            (y) float64 4.427e+06 4.427e+06 ... 4.425e+06 4.425e+06
#     spatial_ref  int32 0
# Attributes:
#     STATISTICS_MAXIMUM:  239
#     STATISTICS_MEAN:     nan
#     STATISTICS_MINIMUM:  32
#     STATISTICS_STDDEV:   nan
#     _FillValue:          -32768.0
#     scale_factor:        1.0
#     add_offset:          0.0

# %%
# Plot each layer or band of the image separately
ep.plot_bands(naip_pre_fire, figsize=(10, 5))
plt.show()

# %%
# Plot color image

ep.plot_rgb(naip_pre_fire.values,
            title="naip data pre-fire")
plt.show()

# %%
# Add the code here to open the raster and read the numpy array inside it
# Create a path for the data file - notice it is a .tif file
naip_post_fire_path = os.path.join("earthpy-downloads",
                                   "naip-before-after",
                                   "post-fire",
                                   "crop",
                                   "m_3910505_nw_13_1_20170902_crop.tif")

naip_post_fire_path
# Out:
# 'earthpy-downloads\\naip-before-after\\post-fire\\crop\\m_3910505_nw_13_1_20170902_crop.tif'

# %%
# Open the data (after-fire) using rioxarray
naip_post_fire = rxr.open_rasterio(naip_post_fire_path)

naip_post_fire
# Out:
# <xarray.DataArray (band: 4, y: 2312, x: 4377)>
# [40478496 values with dtype=int16]
# Coordinates:
#   * band         (band) int32 1 2 3 4
#   * x            (x) float64 4.572e+05 4.572e+05 ... 4.615e+05 4.615e+05
#   * y            (y) float64 4.427e+06 4.427e+06 ... 4.425e+06 4.425e+06
#     spatial_ref  int32 0
# Attributes:
#     STATISTICS_MAXIMUM:  234
#     STATISTICS_MEAN:     63.874147003881
#     STATISTICS_MINIMUM:  6
#     STATISTICS_STDDEV:   47.250919834769
#     _FillValue:          -32768.0
#     scale_factor:        1.0
#     add_offset:          0.0

# %%
# Plot each layer or band of the image separately
ep.plot_bands(naip_post_fire, figsize=(10, 5))
plt.show()

# %%
# Plot rgb image (post-fire)

ep.plot_rgb(naip_post_fire.values,
            title="naip data psot-fire")
plt.show()
